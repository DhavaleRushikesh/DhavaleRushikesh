# %% [markdown]
# # Exploratory Data Analysis of Unicorn Companies Dataset

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Unicorn_Companies.csv')

# %%
df
# Out:
#            Company Valuation ($B) Date Joined        Country           City  \
# 0        Bytedance           $140  04-07-2017          China        Beijing
# 1           SpaceX         $100.3  12-01-2012  United States      Hawthorne
# 2           Stripe            $95   1/23/2014  United States  San Francisco
# 3           Klarna          $45.6  12-12-2011         Sweden      Stockholm
# 4       Epic Games            $42  10/26/2018  United States           Cary
# ...            ...            ...         ...            ...            ...
# 1032     Timescale             $1   2/22/2022  United States       New York
# 1033      Scalapay             $1   2/23/2022          Italy          Milan
# 1034  Omada Health             $1   2/23/2022  United States  San Francisco
# 1035    BlueVoyant             $1   2/23/2022  United States       New York
# 1036          Veev             $1   2/24/2022  United States      San Mateo
#
#                           Industry  \
# ...

# %%
df.shape   # 1037 rows and 13 columns
# Out:
# (1037, 13)

# %%
df.columns
# Out:
# Index(['Company', 'Valuation ($B)', 'Date Joined', 'Country', 'City',
#        'Industry', 'Select Inverstors', 'Founded Year', 'Total Raised',
#        'Financial Stage', 'Investors Count', 'Deal Terms', 'Portfolio Exits'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037 entries, 0 to 1036
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1037 non-null   object
#  1   Valuation ($B)     1037 non-null   object
#  2   Date Joined        1037 non-null   object
#  3   Country            1037 non-null   object
#  4   City               1037 non-null   object
#  5   Industry           1037 non-null   object
#  6   Select Inverstors  1037 non-null   object
#  7   Founded Year       1037 non-null   object
#  8   Total Raised       1037 non-null   object
#  9   Financial Stage    1037 non-null   object
#  10  Investors Count    1037 non-null   object
#  11  Deal Terms         1037 non-null   object
#  12  Portfolio Exits    1037 non-null   object
# dtypes: object(13)
# memory usage: 105.4+ KB

# %%
df.isna().sum()
# Out:
# Company              0
# Valuation ($B)       0
# Date Joined          0
# Country              0
# City                 0
# Industry             0
# Select Inverstors    0
# Founded Year         0
# Total Raised         0
# Financial Stage      0
# Investors Count      0
# Deal Terms           0
# Portfolio Exits      0
# dtype: int64

# %%
df.describe()
# Out:
#        Company Valuation ($B) Date Joined        Country           City  \
# count     1037           1037        1037           1037           1037
# unique    1035            200         623             46            256
# top       Bolt             $1   7/13/2021  United States  San Francisco
# freq         2            244           9            536            145
#
#        Industry Select Inverstors Founded Year Total Raised Financial Stage  \
# count      1037              1037         1037         1037            1037
# unique       33              1006           37          914              10
# top     Fintech              None         2015         None            None
# freq        205                17          144           24             988
#
#        Investors Count Deal Terms Portfolio Exits
# count             1037       1037            1037
# unique              54         16               5
# top                 10          1            None
# ...

# %%
del df['Financial Stage']
del df['Portfolio Exits']

# %%
df = df.rename(columns={'Valuation ($B)': 'Valuation'})
df
# Out:
#            Company Valuation Date Joined        Country           City  \
# 0        Bytedance      $140  04-07-2017          China        Beijing
# 1           SpaceX    $100.3  12-01-2012  United States      Hawthorne
# 2           Stripe       $95   1/23/2014  United States  San Francisco
# 3           Klarna     $45.6  12-12-2011         Sweden      Stockholm
# 4       Epic Games       $42  10/26/2018  United States           Cary
# ...            ...       ...         ...            ...            ...
# 1032     Timescale        $1   2/22/2022  United States       New York
# 1033      Scalapay        $1   2/23/2022          Italy          Milan
# 1034  Omada Health        $1   2/23/2022  United States  San Francisco
# 1035    BlueVoyant        $1   2/23/2022  United States       New York
# 1036          Veev        $1   2/24/2022  United States      San Mateo
#
#                           Industry  \
# 0          Artificial intelligence
# 1                            Other
# ...

# %%
cols = ['Valuation']
for i in cols:
    df[i] = df[i].map(lambda x: str(x).lstrip('$')).astype(float)

df
# Out:
#            Company  Valuation Date Joined        Country           City  \
# 0        Bytedance      140.0  04-07-2017          China        Beijing
# 1           SpaceX      100.3  12-01-2012  United States      Hawthorne
# 2           Stripe       95.0   1/23/2014  United States  San Francisco
# 3           Klarna       45.6  12-12-2011         Sweden      Stockholm
# 4       Epic Games       42.0  10/26/2018  United States           Cary
# ...            ...        ...         ...            ...            ...
# 1032     Timescale        1.0   2/22/2022  United States       New York
# 1033      Scalapay        1.0   2/23/2022          Italy          Milan
# 1034  Omada Health        1.0   2/23/2022  United States  San Francisco
# 1035    BlueVoyant        1.0   2/23/2022  United States       New York
# 1036          Veev        1.0   2/24/2022  United States      San Mateo
#
#                           Industry  \
# 0          Artificial intelligence
# ...

# %% [markdown]
# # Top 10 companies as per top valuation

# %%
data_company_valuation = df.loc[:,['Company','Valuation']].head(10)
data_company_valuation
# Out:
#         Company  Valuation
# 0     Bytedance      140.0
# 1        SpaceX      100.3
# 2        Stripe       95.0
# 3        Klarna       45.6
# 4    Epic Games       42.0
# 5         Canva       40.0
# 6  Checkout.com       40.0
# 7     Instacart       39.0
# 8    Databricks       38.0
# 9       Revolut       33.0

# %%
data_company_valuation.Company
# Out:
# 0       Bytedance
# 1          SpaceX
# 2          Stripe
# 3          Klarna
# 4      Epic Games
# 5           Canva
# 6    Checkout.com
# 7       Instacart
# 8      Databricks
# 9         Revolut
# Name: Company, dtype: object

# %%
data_company_valuation.Valuation
# Out:
# 0    140.0
# 1    100.3
# 2     95.0
# 3     45.6
# 4     42.0
# 5     40.0
# 6     40.0
# 7     39.0
# 8     38.0
# 9     33.0
# Name: Valuation, dtype: float64

# %%
df
# Out:
#            Company  Valuation Date Joined        Country           City  \
# 0        Bytedance      140.0  04-07-2017          China        Beijing
# 1           SpaceX      100.3  12-01-2012  United States      Hawthorne
# 2           Stripe       95.0   1/23/2014  United States  San Francisco
# 3           Klarna       45.6  12-12-2011         Sweden      Stockholm
# 4       Epic Games       42.0  10/26/2018  United States           Cary
# ...            ...        ...         ...            ...            ...
# 1032     Timescale        1.0   2/22/2022  United States       New York
# 1033      Scalapay        1.0   2/23/2022          Italy          Milan
# 1034  Omada Health        1.0   2/23/2022  United States  San Francisco
# 1035    BlueVoyant        1.0   2/23/2022  United States       New York
# 1036          Veev        1.0   2/24/2022  United States      San Mateo
#
#                           Industry  \
# 0          Artificial intelligence
# ...

# %%
plt.bar(data_company_valuation.Company,data_company_valuation.Valuation,width = 0.5,color = 'y')
plt.xticks(rotation = 45)
plt.show()

# %%
import seaborn as sns
sns.barplot(x=df.Company[:10],y=df.Valuation[:10])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Conclusion1 :- Bytedance company has greatest valuation  and Revolute has lowest

# %% [markdown]
# # Finding out the largest % of area of Industry

# %%
df.Industry
# Out:
# 0            Artificial intelligence
# 1                              Other
# 2                            Fintech
# 3                            Fintech
# 4                              Other
#                     ...
# 1032    Internet software & services
# 1033                         Fintech
# 1034                          Health
# 1035                   Cybersecurity
# 1036    Internet software & services
# Name: Industry, Length: 1037, dtype: object

# %%
df.Industry.value_counts().head()
# Out:
# Fintech                            205
# Internet software & services       192
# E-commerce & direct-to-consumer    107
# Artificial intelligence             71
# Health                              69
# Name: Industry, dtype: int64

# %%
data = df.Industry.value_counts().head()
data
plt.pie(data,autopct = '%.f%%',labels = ['Fintech','Internet software & services','E-commerce & direct-to-consumer','Artificial intelligence','Health'],
                                   explode = [0.2,0,0,0,0])
plt.show()

# %% [markdown]
# # Conclusion 2:-
#
# The Fintech industrys are the topmost at various Unicorn comapnies which is there after followed by Internet software & services.The E-commerce industrys is having only 17% in companies and 11% same for both Health and AI industries.Other than these five all the remaining are lower % than this.

# %% [markdown]
# # Topmost contries which has more Unicorn Companies

# %%
df
# Out:
#            Company  Valuation Date Joined        Country           City  \
# 0        Bytedance      140.0  04-07-2017          China        Beijing
# 1           SpaceX      100.3  12-01-2012  United States      Hawthorne
# 2           Stripe       95.0   1/23/2014  United States  San Francisco
# 3           Klarna       45.6  12-12-2011         Sweden      Stockholm
# 4       Epic Games       42.0  10/26/2018  United States           Cary
# ...            ...        ...         ...            ...            ...
# 1032     Timescale        1.0   2/22/2022  United States       New York
# 1033      Scalapay        1.0   2/23/2022          Italy          Milan
# 1034  Omada Health        1.0   2/23/2022  United States  San Francisco
# 1035    BlueVoyant        1.0   2/23/2022  United States       New York
# 1036          Veev        1.0   2/24/2022  United States      San Mateo
#
#                           Industry  \
# 0          Artificial intelligence
# ...

# %%
c = df.Country.value_counts().head(10)
c
# Out:
# United States     536
# China             168
# India              63
# United Kingdom     42
# France             24
# Germany            24
# Israel             20
# Canada             19
# Brazil             16
# South Korea        12
# Name: Country, dtype: int64

# %%
c.index

# %%
c.values

# %%
plt.bar(c.index,c.values)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.barplot(c.index,c.values)
plt.xticks(rotation =90)
plt.show()
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Conclusion 3: The more than 500 Unicorn companies belongs to USA and very less i.e  only 12 belongs to South Korea
